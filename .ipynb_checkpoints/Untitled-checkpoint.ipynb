# %%
from scipy import stats
import numpy as np
np.random.seed(12345678)

# %%
rvs1 = stats.norm.rvs(loc=5,scale=10,size=625)
rvs2 = stats.norm.rvs(loc=5,scale=10,size=625)

# %%
x=np.reshape(np.array(rvs1),(25,25))

# %%
y=np.reshape(np.array(rvs2),(25,25))

# %%
y.shape
# Out:
# (25, 25)

# %%
y
# Out:
# array([[ 2.24921178e+01, -8.38730856e+00,  1.64639065e+01,
#          6.71757281e+00, -1.11064904e+00,  1.01028815e+01,
#          1.57030549e+01,  1.59213537e+01,  1.80646787e+01,
#         -4.94418574e+00,  1.22430376e+01, -5.48811487e+00,
#          1.53781501e+01,  1.71912295e+01, -3.42387065e+00,
#          8.65939063e+00, -4.31519856e+00,  1.54606330e+01,
#          4.19553331e+00,  2.47099549e+01,  2.12929202e+01,
#         -1.29151497e+01,  9.94879901e+00,  1.55156323e+00,
#          1.33086019e+01],
#        [ 8.38984751e+00,  1.22427458e+01, -8.09346222e+00,
#          1.73556460e+01,  8.55793883e+00, -1.28174585e+01,
#          2.09149950e+00, -6.08672264e+00,  6.68101400e-01,
#          1.06069981e+01,  1.21547846e+01, -6.58174040e-02,
#          4.69334152e+00,  1.33277996e+01, -3.44304757e-01,
#          3.94327178e+00, -5.97020997e+00,  7.91751154e+00,
#         -5.39278366e+00, -9.22759999e-02, -5.09067766e+00,
# ...

# %%
stats.ttest_rel(x,y)
# Out:
# Ttest_relResult(statistic=array([ 0.01162003, -0.37697777, -0.71302211, -0.25601824, -0.36655482,
#         1.75683505,  1.87730413, -0.17068735, -0.64661338, -0.1365532 ,
#         0.09605753,  1.67303545, -1.12761016, -1.88740513,  2.01768927,
#         0.53765309, -0.45825492,  1.34587785, -0.94551533,  0.70617348,
#        -0.69121605,  0.85117845,  0.48613501,  2.15459059,  0.1509849 ]), pvalue=array([0.99082482, 0.70950285, 0.48270795, 0.80011841, 0.71716293,
#        0.0916989 , 0.07268381, 0.86590043, 0.5240184 , 0.892523  ,
#        0.92427248, 0.10730726, 0.27063204, 0.07125743, 0.05493797,
#        0.59576738, 0.65089175, 0.19091891, 0.35381864, 0.48687955,
#        0.49606199, 0.40308333, 0.63128077, 0.04144485, 0.88124952]))
